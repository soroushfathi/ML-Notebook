# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Principal Component Analysis
#
# we create a gaussian blob that is rotated:

# %%
rnd = np.random.RandomState(5)
X_ = rnd.normal(size=(300, 2))  # create 300 sample with 2 feature
X_blob  = np.dot(X_, rnd.normal(size=(2, 2))) + rnd.normal(size=2)
y = X_[:, 0] > 0
plt.scatter(X_blob[:, 0], X_blob[:, 1], c=y, linewidths=0, s=30)
plt.xlabel("feature 1")
plt.ylabel("feature 2")
# Out:
# Text(0, 0.5, 'feature 2')

# %%
from sklearn.decomposition import PCA
pca = PCA()

# %% [markdown]
# Then we fit the PCA model with our data. As PCA is an unsupervised algorithm, there is no output `y`.

# %%
pca.fit(X_blob)
# Out:
# PCA()

# %% [markdown]
# then we can transform data, projected on the principal components:

# %%
X_pca = pca.transform(X_blob)

plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, linewidths=0, s=30)
plt.xlabel("firstt principal component")
plt.ylabel("firstt principal component");
